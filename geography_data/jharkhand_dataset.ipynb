# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("jharkhand-data-set.csv")

# %%
df
# Out:
#         Month Water level Discharge
# 0        june           2         3
# 1        june        0.00      0.00
# 2        june        0.00      0.00
# 3        june        0.00      0.00
# 4        june        0.00      0.00
# ..        ...         ...       ...
# 188  november      191.02      3.38
# 189  november      191.02      3.38
# 190  november      190.99      3.12
# 191  november           -         -
# 192       NaN         NaN       NaN
#
# [193 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Month          1
# Water level    1
# Discharge      1
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Month          0
# Water level    0
# Discharge      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 192 entries, 0 to 191
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        192 non-null    object
#  1   Water level  192 non-null    object
#  2   Discharge    192 non-null    object
# dtypes: object(3)
# memory usage: 6.0+ KB

# %%
df['Water level'] = df['Water level'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df['Water level'] = df['Water level'].astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
# ...

# %%
df_june = df[df['Month'] == 'june']

# %%
df_june.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, 0 to 31
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        32 non-null     object
#  1   Water level  32 non-null     object
#  2   Discharge    32 non-null     object
# dtypes: object(3)
# memory usage: 1.0+ KB

# %%
# Assuming the two columns are named 'Column1' and 'Column2'
x = df_june['Water level']
y = df_june['Discharge']

plt.figure(figsize=(10, 10))
plt.plot(x, y, marker='o', linestyle='-', color='blue', label='Connection')
plt.title('Connection Between Water level and Discharge in june')
plt.xlabel('Water level')
plt.ylabel('Discharge')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20, 10))

# Plot for Column1
sns.histplot(x, kde=True, color='blue', label='Column1', bins=10)

# Plot for Column2
sns.histplot(y, kde=True, color='green', label='Column2', bins=10)

# Add labels, legend, and title
plt.title('Histogram of Column1 and Discharge')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='blue', marker='o', label='Water Level vs Discharge')

# Add titles and labels
plt.title('Relationship Between Water Level and Discharge')
plt.xlabel('Water Level')
plt.ylabel('Discharge')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # for lineplot

# %%
sns.lineplot(data=df_june,x=x,y=y)
# Out:
# <Axes: xlabel='Water level', ylabel='Discharge'>

# %%
sns.heat
