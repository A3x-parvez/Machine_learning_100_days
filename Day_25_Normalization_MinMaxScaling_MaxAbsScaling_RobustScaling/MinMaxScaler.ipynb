# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wine_data.csv',header=None)

# %%
df=df.iloc[:,:3]
df.columns=["Class_label","Alcohol","Mallic_acid"]

# %%
df
# Out:
#      Class_label  Alcohol  Mallic_acid
# 0              1    14.23         1.71
# 1              1    13.20         1.78
# 2              1    13.16         2.36
# 3              1    14.37         1.95
# 4              1    13.24         2.59
# ..           ...      ...          ...
# 173            3    13.71         5.65
# 174            3    13.40         3.91
# 175            3    13.27         4.28
# 176            3    13.17         2.59
# 177            3    14.13         4.10
#
# [178 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Class_label    0
# Alcohol        0
# Mallic_acid    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
color_dict={1:'red',3:'green',2:'blue'}
sns.scatterplot(data=df,x='Alcohol',y='Mallic_acid',hue=df['Class_label'],palette=color_dict)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Mallic_acid'>

# %%
sns.kdeplot(df["Alcohol"])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(df["Mallic_acid"])
# Out:
# <Axes: xlabel='Mallic_acid', ylabel='Density'>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop('Class_label',axis=1),df['Class_label'],test_size=0.3,random_state=0)

# %%
X_train.shape , X_test.shape
# Out:
# ((124, 2), (54, 2))

# %%
X_test.columns
# Out:
# Index(['Alcohol', 'Mallic_acid'], dtype='object')

# %%
y_train
# Out:
# 22     1
# 108    2
# 175    3
# 145    3
# 71     2
#       ..
# 103    2
# 67     2
# 117    2
# 47     1
# 172    3
# Name: Class_label, Length: 124, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
# X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
X_train_scaled.describe()
# Out:
#           Alcohol  Mallic_acid
# count  124.000000   124.000000
# mean     0.525017     0.313805
# std      0.215414     0.238802
# min      0.000000     0.000000
# 25%      0.358199     0.150735
# 50%      0.540323     0.209034
# 75%      0.701613     0.495273
# max      1.000000     1.000000

# %%
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15020\3996987463.py in ?()
# ----> 1 X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, data, index, columns, dtype, copy)
#     882                 )
#     883         # For data is scalar
#     884         else:
#     885             if index is None or columns is None:
# --> 886                 raise ValueError("DataFrame constructor not properly called!")
#     887
#     888             index = ensure_index(index)
#     889             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!

# %%
X_test_scaled

# %%
X_train_scaled
