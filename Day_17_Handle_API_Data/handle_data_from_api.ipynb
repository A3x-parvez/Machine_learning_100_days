# %%
API_key = "954bf7f33310b56773bdaa94422bdf4c"

# %%
import requests

url = "https://api.themoviedb.org/3/authentication"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5NTRiZjdmMzMzMTBiNTY3NzNiZGFhOTQ0MjJiZGY0YyIsIm5iZiI6MTczNjUxOTc5MC4xOTIsInN1YiI6IjY3ODEzMDZlMTI2Njc5Njg4NTRlY2Q4NiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.sHy10E8SXe1uhgpz7iG0CB9c7EO0-WGxyvPPdHhWJew"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"success":true}

# %%
url = f"https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc"
    
headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5NTRiZjdmMzMzMTBiNTY3NzNiZGFhOTQ0MjJiZGY0YyIsIm5iZiI6MTczNjUxOTc5MC4xOTIsInN1YiI6IjY3ODEzMDZlMTI2Njc5Njg4NTRlY2Q4NiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.sHy10E8SXe1uhgpz7iG0CB9c7EO0-WGxyvPPdHhWJew"
    }
    
response = requests.get(url, headers=headers)
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zOpe0eHsq0A2NvNyBbtT6sj53qV.jpg',
#    'genre_ids': [28, 878, 35, 10751],
#    'id': 939243,
#    'original_language': 'en',
#    'original_title': 'Sonic the Hedgehog 3',
#    'overview': 'Sonic, Knuckles, and Tails reunite against a powerful new adversary, Shadow, a mysterious villain with powers unlike anything they have faced before. With their abilities outmatched in every way, Team Sonic must seek out an unlikely alliance in hopes of stopping Shadow and protecting the planet.',
#    'popularity': 4115.631,
#    'poster_path': '/d8Ryb8AunYAuycVKDp5HpdWPKgC.jpg',
#    'release_date': '2024-12-19',
#    'title': 'Sonic the Hedgehog 3',
#    'video': False,
#    'vote_average': 7.6,
#    'vote_count': 431},
#   {'adult': False,
#    'backdrop_path': '/euYIwmwkmz95mnXvufEmbL6ovhZ.jpg',
#    'genre_ids': [28, 12, 18],
#    'id': 558449,
#    'original_language': 'en',
#    'original_title': 'Gladiator II',
# ...

# %%
import requests
def Fetch_pagedata(page):
    url = f"https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page={page}&sort_by=popularity.desc"
    
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5NTRiZjdmMzMzMTBiNTY3NzNiZGFhOTQ0MjJiZGY0YyIsIm5iZiI6MTczNjUxOTc5MC4xOTIsInN1YiI6IjY3ODEzMDZlMTI2Njc5Njg4NTRlY2Q4NiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.sHy10E8SXe1uhgpz7iG0CB9c7EO0-WGxyvPPdHhWJew"
    }
    
    response = requests.get(url, headers=headers)
    return response.json()

# %%
import pandas as pd

# %%
df_raw = pd.DataFrame(response.json()['results'])
df_raw
# Out:
#     adult                     backdrop_path             genre_ids       id  \
# 0   False  /zOpe0eHsq0A2NvNyBbtT6sj53qV.jpg  [28, 878, 35, 10751]   939243
# 1   False  /euYIwmwkmz95mnXvufEmbL6ovhZ.jpg          [28, 12, 18]   558449
# 2   False  /oHPoF0Gzu8xwK4CtdXDaWdcuZxZ.jpg       [12, 10751, 16]   762509
# 3   False  /vZG7PrX9HmdgL5qfZRjhJsFYEIA.jpg         [28, 878, 12]   912649
# 4   False  /k24eZq5I3jyz4htPkZCRpnUmBzE.jpg           [10749, 18]  1156593
# 5   False  /uKb22E0nlzr914bA9KyA5CVCOlV.jpg       [18, 10749, 14]   402431
# 6   False  /tElnmtQ6yz1PjN1kePNl8yMSb59.jpg   [16, 12, 10751, 35]  1241982
# 7   False  /cjEcqdRdPQJhYre3HUAc5538Gk8.jpg          [28, 14, 35]   845781
# 8   False  /A6vAMO3myroRfBwSZetY4GVqaW4.jpg      [16, 14, 28, 12]   839033
# 9   False  /fzjH7kt1017R9EckLDmWmH5pGhD.jpg          [28, 27, 53]   970450
# 10  False  /b3mdmjYTEL70j7nuXATUAD9qgu4.jpg          [16, 14, 12]   823219
# ...

# %%
df_movies = df_raw[['id','title','release_date','overview','popularity','vote_average','vote_count','poster_path']]

# %%
df_movies
# Out:
#          id                                           title release_date  \
# 0    939243                            Sonic the Hedgehog 3   2024-12-19
# 1    558449                                    Gladiator II   2024-11-05
# 2    762509                           Mufasa: The Lion King   2024-12-18
# 3    912649                           Venom: The Last Dance   2024-10-22
# 4   1156593                                      Your Fault   2024-12-26
# 5    402431                                          Wicked   2024-11-20
# 6   1241982                                         Moana 2   2024-11-21
# 7    845781                                         Red One   2024-10-31
# 8    839033  The Lord of the Rings: The War of the Rohirrim   2024-12-05
# 9    970450                                      Werewolves   2024-12-04
# 10   823219                                            Flow   2024-01-30
# 11  1035048                                       Elevation   2024-11-07
# ...

# %% [markdown]
# # create a empty dataframe

# %%
movies = pd.DataFrame()
movies
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # gather data from all pages

# %%
for i in range(1,501):
    movie_json = Fetch_pagedata(i) 
    raw_temp_df = pd.DataFrame(movie_json['results'])
    temp_df = raw_temp_df[['id','title','release_date','overview','popularity','vote_average','vote_count','poster_path']]
    movies = pd.concat([movies, temp_df], ignore_index=True)
    print("page ",i," fetched successfully")
# Out:
# page  1  fetched successfully
# page  2  fetched successfully
# page  3  fetched successfully
# page  4  fetched successfully
# page  5  fetched successfully
# page  6  fetched successfully
# page  7  fetched successfully
# page  8  fetched successfully
# page  9  fetched successfully
# page  10  fetched successfully
# page  11  fetched successfully
# page  12  fetched successfully
# page  13  fetched successfully
# page  14  fetched successfully
# page  15  fetched successfully
# page  16  fetched successfully
# page  17  fetched successfully
# page  18  fetched successfully
# page  19  fetched successfully
# page  20  fetched successfully
# page  21  fetched successfully
# page  22  fetched successfully
# page  23  fetched successfully
# page  24  fetched successfully
# page  25  fetched successfully
# page  26  fetched successfully
# page  27  fetched successfully
# page  28  fetched successfully
# page  29  fetched successfully
# page  30  fetched successfully
# ...

# %%
movies.shape
# Out:
# (10020, 8)

# %%
movies
# Out:
#             id                             title release_date  \
# 0       939243              Sonic the Hedgehog 3   2024-12-19
# 1       558449                      Gladiator II   2024-11-05
# 2       762509             Mufasa: The Lion King   2024-12-18
# 3       912649             Venom: The Last Dance   2024-10-22
# 4      1156593                        Your Fault   2024-12-26
# ...        ...                               ...          ...
# 10015     8265             Welcome to the Sticks   2008-02-20
# 10016   254191                         Honeymoon   2014-09-12
# 10017    32022  Case Closed: Countdown to Heaven   2001-04-21
# 10018    15163                     Amazing Grace   2006-09-16
# 10019     2122               The Whole Ten Yards   2004-04-07
#
#                                                 overview  popularity  \
# 0      Sonic, Knuckles, and Tails reunite against a p...    4115.631
# 1      Years after witnessing the death of the revere...    3555.894
# ...

# %%
movies.to_csv("TMDB_Movies.csv")
